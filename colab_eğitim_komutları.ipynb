# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Learning
# Out:
# /content/drive/MyDrive/Learning

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Learning'

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 49.1 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="G09cdE1QuRUZ1AQ4iLAf")
project = rf.workspace("robot-arzfa").project("pothole-vhmow-cvlrf")
version = project.version(2)
dataset = version.download("yolov8")

# %%
# !yolo detect train model=yolo11s.pt data = "/content/drive/MyDrive/Learning/pothole-2/data.yaml" epochs=150 imgsz=768 batch=8 device = 0 optimizer = SGD lr0 = 0.001
# Out:
# ...
# Ultralytics 8.3.236 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# eğitim kesilirse eğitime devam etme komutu
# !yolo detect train resume=True model=last.pt
